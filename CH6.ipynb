# %%
# This is Ben Robin's ch6 workbook 

country_codes = {'Finalnd': 'fi', 'South Africa': 'za', 'Nepal': 'np'}
country_codes
# Out:
# {'Finalnd': 'fi', 'South Africa': 'za', 'Nepal': 'np'}

# %%
len(country_codes)
# Out:
# 3

# %%
def Check():
    if country_codes:
        print('country_codes is not empty')
    else:
        print('country_codes is empty')
Check()
# Out:
# country_codes is not empty

# %%
country_codes.clear()
Check()
# Out:
# country_codes is empty

# %%
states = {'VT': 'Vermont', 'NH': 'New Hampshire', 'MA': 'Massachusetts'}
states
# Out:
# {'VT': 'Vermont', 'NH': 'New Hampshire', 'MA': 'Massachusetts'}

# %%
days_per_month = {'January': 31, 'February': 28, 'March': 31}
days_per_month
# Out:
# {'January': 31, 'February': 28, 'March': 31}

# %%
for month, days in days_per_month.items():
    print(f'{month} has {days} days')
# Out:
# January has 31 days
# February has 28 days
# March has 31 days

# %%
roman_numerals = {'I':1, 'II':2, 'III':3, 'V':5, 'X':100}
roman_numerals
# Out:
# {'I': 1, 'II': 2, 'III': 3, 'V': 5, 'X': 100}

# %%
roman_numerals['V']
# Out:
# 5

# %%
roman_numerals['X'] = 10 
roman_numerals
# Out:
# {'I': 1, 'II': 2, 'III': 3, 'V': 5, 'X': 10}

# %%
roman_numerals['L'] =50
roman_numerals
# Out:
# {'I': 1, 'II': 2, 'III': 3, 'V': 5, 'X': 10, 'L': 50}

# %%
del roman_numerals['III']

# %%
roman_numerals
# Out:
# {'I': 1, 'II': 2, 'V': 5, 'X': 10, 'L': 50}

# %%
roman_numerals.pop('X')
# Out:
# 10

# %%
roman_numerals
# Out:
# {'I': 1, 'II': 2, 'V': 5, 'L': 50}

# %%
roman_numerals['III']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_61/4078080874.py in <module>
# ----> 1 roman_numerals['III']
#
# KeyError: 'III'

# %%
roman_numerals.get('III','III not in dictionary')
# Out:
# 'III not in dictionary'

# %%
roman_numerals.get('V')
# Out:
# 5

# %%
'V' in roman_numerals
# Out:
# True

# %%
'III' in roman_numerals
# Out:
# False

# %%
'III' not in roman_numerals
# Out:
# True

# %%
# Ben Robin 6.2.4 

months = {'January': 1, 'February': 2,'March': 3}

for month_name in months.keys():
    print(month_name, end=' ')
# Out:
# January February March

# %%
for month_number in months.values():
    print(month_number, end=' ')
# Out:
# 1 2 3

# %%
months_view = months.keys()

for key in months_view:
    print(key, end=' ')
# Out:
# January February March

# %%
months['December']=12
months
# Out:
# {'January': 1, 'February': 2, 'March': 3, 'December': 12}

# %%
for key in months_view:
    print(key,end=' ')
# Out:
# January February March December

# %%
list(months.keys())
# Out:
# ['January', 'February', 'March', 'December']

# %%
list(months.values())
# Out:
# [1, 2, 3, 12]

# %%
list(months.items())
# Out:
# [('January', 1), ('February', 2), ('March', 3), ('December', 12)]

# %%
for month_name in sorted(months.keys()):
    print(month_name, end=" ")
# Out:
# December February January March

# %%
# check for 6.2.4 for the following dictionary, create listes of its keys, values and items and show those lists
roman_numerals = {'I':1, 'II':2, 'III':3, 'V':5}

list(roman_numerals.keys())
# Out:
# ['I', 'II', 'III', 'V']

# %%
list(roman_numerals.values())
# Out:
# [1, 2, 5, 50]

# %%
list(roman_numerals.items())
# Out:
# [('I', 1), ('II', 2), ('III', 3), ('V', 5)]

# %%
# 5.2.5 Dictionary Comparisons Ben Robin

country_capitals1 = {'Belgium': 'Brussels', 'Haiti': 'Port-au-Prince'}
country_capitals2 = {'Nepal': 'Kathmandu', 'Uruguay':'Montevideo'}
country_capitals3 = {'Haiti': 'Port-au-Prince', 'Belgium': 'Brussels'}
country_capitals1 == country_capitals2
# Out:
# False

# %%
country_capitals1 == country_capitals3
# Out:
# True

# %%
country_capitals1 != country_capitals2
# Out:
# True

# %%
# Ben Robin's fig 6_02.py

text = ('this is sample text with several words ' 
        'this is more sample text with some different words')

word_counts = {}

#count occurences of each unique word

for word in text.split():
    if word in word_counts:
        word_counts[word] += 1 
    else:
        word_counts[word] = 1
        
print(f'{"WORD":<12}COUNT')

for word, count in sorted(word_counts.items()):
    print(f'{word:<12}{count}')
    
print('\nNumber of unique words:', len(word_counts))
# Out:
# WORD        COUNT
# different   1
# is          2
# more        1
# sample      2
# several     1
# some        1
# text        2
# this        2
# with        2
# words       2
#
# Number of unique words: 10

# %%
from collections import Counter

text = ('this is a sample text with several different words ' 
        'this is a collection of more sample text with some different words') 

counter = Counter(text.split())

for word, count in sorted(counter.items()):
    print(f'{word:<12}{count}')
# Out:
# a           2
# collection  1
# different   2
# is          2
# more        1
# of          1
# sample      2
# several     1
# some        1
# text        2
# this        2
# with        2
# words       2

# %%
# 6.2.7 self check (2) Ben Robin 

import random

numbers = [random.randrange(1,6) for i in range(50)]

from collections import Counter

counter = Counter(numbers)

for value, count in sorted(counter.items()):
    print(f'{value:<4}{count}')
# Out:
# 1   7
# 2   8
# 3   9
# 4   8
# 5   18
