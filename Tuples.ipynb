# %%
[1, 2, 3] + (4 , 5, 6)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_60/4221947366.py in <module>
# ----> 1 [1, 2, 3] + (4 , 5, 6)
#
# TypeError: can only concatenate list (not "tuple") to list

# %%
student_tuple = ('Amanda', [98, 85, 87])

# %%
first_name, grades = student_tuple
first_name
# Out:
# 'Amanda'

# %%
number1, number2, number3 = [2, 3, 4]
print(f'{number1} {number2} {number3}')
# Out:
# 2 3 4

# %%
print(f'first number ={number1}; second number ={number2}')
# Out:
# first number =2; second number =3

# %%
colors = ['red', 'orange', 'yellow']
list(enumerate(colors))
# Out:
# [(0, 'red'), (1, 'orange'), (2, 'yellow')]

# %%
for index, value in enumerate(colors):
    print(f'{index}: {value}')
# Out:
# 0: red
# 1: orange
# 2: yellow

# %%
#fig05_01.py
"""Diplaying a bar chart - Ben Robin"""
numbers = [19, 3,15,7,11]

print('\ncCeating a bar chart from numbers:')
print(f'Index{"Value":>8}    Bar')

for index, value in enumerate(numbers):
    print(f'{index:>5}{value:>8}   {"*" * value}')
# Out:
# cCeating a bar chart from numbers:
# Index   Value    Bar
#     0      19   *******************
#     1       3   ***
#     2      15   ***************
#     3       7   *******
#     4      11   ***********
